# %%
import pandas as pd
import numpy as np
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(14, 8)})

# %%
def scoring(clusterization, y_true, X):
    print(f'Number of clusters: {len(np.unique(y_true))} Estimated number of clusters: {len(np.unique(clusterization.labels_))}')
    print(f'Homogenity: {metrics.homogeneity_score(y_true, clusterization.labels_)}')
    print(f'Completeness: {metrics.completeness_score(y_true, clusterization.labels_)}')
    print(f'V measure: {metrics.v_measure_score(y_true, clusterization.labels_)}')

# %%
np.random.seed(0)
X = np.random.randn(30000, 2)
y = np.logical_xor(X[:, 0]>0, X[:, 1]>0)

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# linkage='ward'

# %%
from sklearn.cluster import AgglomerativeClustering

clustering = AgglomerativeClustering(linkage='ward')

# %%
# %%time
clustering.fit(X)
# Out:
# Wall time: 1min 23s
# AgglomerativeClustering()

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=clustering.labels_)
# Out:
# <AxesSubplot:>

# %%
scoring(clustering, y, X)
# Out:
# Number of clusters: 2 Estimated number of clusters: 2
# Homogenity: 0.005686383446603616
# Completeness: 0.005695153036118505
# V measure: 0.005690764862832144

# %% [markdown]
# linkage='complete'

# %%
clustering = AgglomerativeClustering(linkage='complete')

# %%
# %%time
clustering.fit(X)
# Out:
# Wall time: 1min 21s
# AgglomerativeClustering(linkage='complete')

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=clustering.labels_)
# Out:
# <AxesSubplot:>

# %%
scoring(clustering, y, X)
# Out:
# Number of clusters: 2 Estimated number of clusters: 2
# Homogenity: 0.002311905022829213
# Completeness: 0.010463600936208114
# V measure: 0.003787067477227782

# %% [markdown]
# linkage='average'

# %%
clustering = AgglomerativeClustering(linkage='average')

# %%
# %%time
clustering.fit(X)
# Out:
# Wall time: 1min 42s
# AgglomerativeClustering(linkage='average')

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=clustering.labels_)
# Out:
# <AxesSubplot:>

# %%
scoring(clustering, y, X)
# Out:
# Number of clusters: 2 Estimated number of clusters: 2
# Homogenity: 8.135990712589502e-06
# Completeness: 0.00552328742012105
# V measure: 1.6248047497161238e-05

# %% [markdown]
# linkage='single'

# %%
clustering = AgglomerativeClustering(linkage='single')

# %%
# %%time
clustering.fit(X)
# Out:
# Wall time: 16.8 s
# AgglomerativeClustering(linkage='single')

# %%
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=clustering.labels_)
# Out:
# <AxesSubplot:>

# %%
scoring(clustering, y, X)
# Out:
# Number of clusters: 2 Estimated number of clusters: 2
# Homogenity: 3.336942779564269e-05
# Completeness: 0.06135833424163403
# V measure: 6.67025797219137e-05

# %% [markdown]
# Я не знаю який алгоритм кластеризації зможе розділити логічний ксор
